# %%
import openpyxl
#import pandas as pd

#wb = pd.read_excel("produceSales.xlsx", sheet_name = 'Sheet')
#wb.head()

# %%
wb = openpyxl.load_workbook('produceSales.xlsx')
sheet = wb.get_sheet_by_name('Sheet')
sheet
# Out:
# C:\Users\Administrator\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
# <Worksheet "Sheet">

# %%
sheet.max_row
# Out:
# 23758

# %%
price = {'Garlic' : 3.07, 'Celery' : 1.19, 'Lemon' : 1.27}

# %%
#wb.shape

# %%
for rowNum in range(2, sheet.max_row):
    produceName = sheet.cell(row = rowNum, column = 1).value
    if produceName in price:
        sheet.cell(row=rowNum, column=2).value = price[produceName]

wb.save('updated.xlsx')

# %%
### 판다스로 짜기

import pandas as pd

wb = pd.read_excel("produceSales.xlsx", sheet_name = 'Sheet')

wb.iloc[0,0]
# Out:
# 'Potatoes'

# %%
for rowNum in range(1,23757):
    produceName = wb.iloc[rowNum,0]
    if produceName in price:
        wb.iloc[rowNum,1]=price[produceName]
wb
# Out:
#                 PRODUCE  COST PER POUND  POUNDS SOLD   TOTAL
# 0              Potatoes            0.86         21.6   18.58
# 1                  Okra            2.26         38.6   87.24
# 2            Fava beans            2.69         32.8   88.23
# 3            Watermelon            0.66         27.3   18.02
# 4                Garlic            3.07          4.9    5.83
# 5              Parsnips            2.27          1.1    2.50
# 6             Asparagus            2.49         37.9   94.37
# 7              Avocados            3.23          9.2   29.72
# 8                Celery            1.19         28.9   88.72
# 9                  Okra            2.26         40.0   90.40
# 10              Spinach            4.12         30.0  123.60
# 11             Cucumber            1.07         36.0   38.52
# 12             Apricots            3.71         29.4  109.07
# 13                 Okra            2.26          9.5   21.47
# ...
